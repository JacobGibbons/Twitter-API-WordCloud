# %%
# %matplotlib inline  
from sentiment import Sentiment

s = Sentiment('VandB_TweetList.txt')
wordlist = (['RT','co','https','http','Baroda','Vadodara','SmartCitiesIndia'])

s.show_worldcloud(wordlist)

# %%
s.show_piechart()
s.print_sentiment_extremes()
# Out:
# If you feel we can be part of this wonderful journey of making citizens in #Vadodara Safer, please reach out to us…  1.0
# This Rainy Season adds a splash of color to your wardrobe with our beautiful collection from Rang.  Visit Us: 2- Ra…  0.85
# Make your monsoon thrive and bloom! Put yourself in the mood for the season with dresses from Rang's latest collect…  0.5
# #Vadodara #Traffic_Police collected fine of #42,000.00 from over speeding drivers in the city. The teams with the h…  0.4166666666666667
# #smartsolution Two wheeler riders with helmet can get free parking to all malls, cinemas Etc. and without helmet sh…  0.4

# %%
s.show_hist()

# %%
s.FrequencyTimeGraph('Mall')
