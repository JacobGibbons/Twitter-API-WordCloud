# %%
# %matplotlib inline  
from sentiment import Sentiment

s = Sentiment('Reading_TweetList.txt')
wordlist = ['RT','co','https','http','rdguk']

s.show_worldcloud(wordlist)

# %%
s.show_piechart()
s.print_sentiment_extremes()
# Out:
# An excellent three bedroom semi-detached home is sold with the advantage of no chain in Patrick Road, Caversham,…  1.0
# Exciting news! We’re having a picnic! Bring your children, friends and family - all welcome! Meet at the cafe at 5p…  0.734375
# @UKCareersFair have a Careers Fair coming up at The Pavillion in Reading (Oxford Road) THIS Friday (19th) from 10am…  0.7
# Always good to catch up with   &amp  _RDG to discuss joint #Newbury  #rdguk matters inc cou   0.7
# An excellent opportunity to purchase this individual, character detached, 3 bedrooms home providing surprisingly sp…  0.5666666666666667

# %%
s.show_hist()

# %%
s.FrequencyTimeGraph('Road')
